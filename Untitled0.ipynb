# %%
# !pip install -q imbalanced-learn

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94830c06-19a6-4b8f-95be-1f915d97250b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94830c06-19a6-4b8f-95be-1f915d97250b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('creditcard.csv.zip', 'r') as zip_ref:
    zip_ref.extractall()

import pandas as pd
df = pd.read_csv('creditcard.csv')
df.head()

# %%
print(lr_pipeline)
print(rf_pipeline)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('smote', SMOTE(random_state=42)),
#                 ('classifier',
#                  LogisticRegression(max_iter=1000, random_state=42))])
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
from sklearn.model_selection import GridSearchCV

lr_params = {
    'smote__k_neighbors': [3, 5],
    'classifier__C': [0.01, 0.1, 1.0]
}

rf_params = {
    'smote__k_neighbors': [3, 5],
    'classifier__max_depth': [10, 20, None]
}

lr_grid = GridSearchCV(lr_pipeline, lr_params, scoring='roc_auc', cv=5, n_jobs=-1)
lr_grid.fit(X_train, y_train)

print("Logistic Regression done.")
print("Best LR params:", lr_grid.best_params_)
# Out:
# Logistic Regression done.
# Best LR params: {'classifier__C': 0.01, 'smote__k_neighbors': 3}

# %%
print(df.shape)
print(df['Class'].value_counts(normalize=True))
# Out:
# (284807, 31)
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Class', axis=1)
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

print(X_train.shape, X_test.shape)
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# (227845, 30) (56962, 30)
# Class
# 0    0.998271
# 1    0.001729
# Name: proportion, dtype: float64
# Class
# 0    0.99828
# 1    0.00172
# Name: proportion, dtype: float64

# %%
# !pip install -q imbalanced-learn  # skip if already installed this session

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Logistic Regression needs scaling
lr_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE(random_state=42)),
    ('classifier', LogisticRegression(max_iter=1000, random_state=42))
])

# Random Forest doesn't need scaling
rf_pipeline = Pipeline([
    ('smote', SMOTE(random_state=42)),
    ('classifier', RandomForestClassifier(random_state=42))
])

# %%
rf_pipeline = Pipeline([
    ('smote', SMOTE(random_state=42, k_neighbors=5)),
    ('classifier', RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1))
])

rf_grid = GridSearchCV(rf_pipeline, {'classifier__max_depth': [10, 20]}, scoring='roc_auc', cv=3, n_jobs=-1)
rf_grid.fit(X_train, y_train)

print("Best RF params:", rf_grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3572/2882905274.py in <cell line: 0>()
#       5
#       6 rf_grid = GridSearchCV(rf_pipeline, {'classifier__max_depth': [10, 20]}, scoring='roc_auc', cv=3, n_jobs=-1)
# ----> 7 rf_grid.fit(X_train, y_train)
#       8
#       9 print("Best RF params:", rf_grid.best_params_)
#
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.13/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

rf_pipeline = Pipeline([
    ('smote', SMOTE(random_state=42, k_neighbors=5)),
    ('classifier', RandomForestClassifier(n_estimators=50, max_depth=10, random_state=42, n_jobs=-1))
])

rf_pipeline.fit(X_train, y_train)
print("RF training done.")
# Out:
# RF training done.

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

# Logistic Regression (from GridSearchCV)
y_pred_lr = lr_grid.predict(X_test)
y_proba_lr = lr_grid.predict_proba(X_test)[:, 1]

print("=== Logistic Regression ===")
print(confusion_matrix(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr, digits=3))
print("ROC-AUC:", roc_auc_score(y_test, y_proba_lr))

# Random Forest (direct fit)
y_pred_rf = rf_pipeline.predict(X_test)
y_proba_rf = rf_pipeline.predict_proba(X_test)[:, 1]

print("\n=== Random Forest ===")
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf, digits=3))
print("ROC-AUC:", roc_auc_score(y_test, y_proba_rf))
# Out:
# === Logistic Regression ===
# [[55431  1433]
#  [    8    90]]
#               precision    recall  f1-score   support
#
#            0      1.000     0.975     0.987     56864
#            1      0.059     0.918     0.111        98
#
#     accuracy                          0.975     56962
#    macro avg      0.529     0.947     0.549     56962
# weighted avg      0.998     0.975     0.986     56962
#
# ROC-AUC: 0.971903065531221
#
# === Random Forest ===
# [[56782    82]
#  [   11    87]]
#               precision    recall  f1-score   support
#
#            0      1.000     0.999     0.999     56864
#            1      0.515     0.888     0.652        98
#
#     accuracy                          0.998     56962
#    macro avg      0.757     0.943     0.825     56962
# weighted avg      0.999     0.998     0.999     56962
#
# ROC-AUC: 0.9853427583751565

# %%
print("RF ROC-AUC:", roc_auc_score(y_test, y_proba_rf))
# Out:
# RF ROC-AUC: 0.9853427583751565

# %% [markdown]
# This project tackled fraud detection on a highly imbalanced dataset (284,807 transactions, only 0.17% fraudulent). Since accuracy is a misleading metric here — a model predicting "legitimate" for everything would score 99.83% accuracy while catching zero fraud — precision, recall, and ROC-AUC were used instead. SMOTE was applied strictly within the training fold using an imblearn Pipeline to prevent data leakage into the test set. Two models were trained and tuned: Logistic Regression and Random Forest. Logistic Regression caught slightly more fraud cases (recall 0.918) but produced 1,433 false positives, which would be impractical in production. Random Forest offered a much stronger balance, catching 87 of 98 fraud cases (recall 0.888) with only 82 false positives (precision 0.515, F1-score 0.652) and the highest ROC-AUC (0.985). Random Forest is therefore the recommended model, as it minimizes unnecessary transaction declines while maintaining strong fraud detection capability.
